# %%
import scipy.linalg as sp
import numpy as np

# %%
a = np.array([[1, -2, 3],
 [4, 5, 6],
 [7, 1, 9]])

# %%
b = np.array([1, 2, 3])

# %%
x = sp.solve(a,b)

# %%
a
# Out:
# array([[ 1, -2,  3],
#        [ 4,  5,  6],
#        [ 7,  1,  9]])

# %%
b
# Out:
# array([1, 2, 3])

# %%
a@x
# Out:
# array([1., 2., 3.])

# %%
B = np.random.rand(3,3)

# %%
B
# Out:
# array([[0.21819304, 0.64319599, 0.92159693],
#        [0.54698198, 0.03884771, 0.39080884],
#        [0.45345573, 0.50453189, 0.33246663]])

# %%
X = sp.solve(a,B)

# %%
a@X
# Out:
# array([[0.21819304, 0.64319599, 0.92159693],
#        [0.54698198, 0.03884771, 0.39080884],
#        [0.45345573, 0.50453189, 0.33246663]])

# %%
val, vec = sp.eig(a)

# %%
val
# Out:
# array([-1.13261772+0.j, 10.67269524+0.j,  5.45992248+0.j])

# %%
vec
# Out:
# array([[-0.8215735 ,  0.05324273,  0.25636602],
#        [-0.02150583,  0.74309552, -0.93563185],
#        [ 0.56969684,  0.66706391, -0.24263037]])

# %%
sp.inv(a)
# Out:
# array([[-0.59090909, -0.31818182,  0.40909091],
#        [-0.09090909,  0.18181818, -0.09090909],
#        [ 0.46969697,  0.22727273, -0.1969697 ]])

# %%
sp.det(a)
# Out:
# np.float64(-66.0)

# %%
sp.norm(a)
# Out:
# np.float64(14.89966442575134)
